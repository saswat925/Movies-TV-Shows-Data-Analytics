# %%
import pandas as pd
from sqlalchemy import create_engine
import urllib

# %% [markdown]
#      connection string sql srever

# %%
server = "LAPTOP-71G1NMQR\\SQLEXPRESS"
database = "OTT_DB"

params = urllib.parse.quote_plus(
    f"DRIVER={{ODBC Driver 18 for SQL Server}};"
    f"SERVER={server};"
    f"DATABASE={database};"
    "Trusted_Connection=yes;"
    "TrustServerCertificate=yes;"
)

engine = create_engine(f"mssql+pyodbc:///?odbc_connect={params}")

print("SQL Server Connected Successfully")
# Out:
# SQL Server Connected Successfully

# %% [markdown]
#     Load data from sqk serever

# %%
movies = pd.read_sql("SELECT * FROM final_movies", engine)
tvshows = pd.read_sql("SELECT * FROM final_tvshows", engine)

print(movies.head())
print(tvshows.head())
# Out:
#    show_id   type                                        title  \
# 0      189  Movie                 Sin City: A Dame to Kill For
# 1     1771  Movie           Captain America: The First Avenger
# 2     1865  Movie  Pirates of the Caribbean: On Stranger Tides
# 3     1930  Movie                       The Amazing Spider-Man
# 4     4258  Movie                                Scary Movie 5
#
#                          director  \
# 0  Frank Miller, Robert Rodriguez
# 1                    Joe Johnston
# 2                    Rob Marshall
# 3                       Marc Webb
# 4                  Malcolm D. Lee
#
#                                         cast_members  \
# 0  Jessica Alba, Bruce Willis, Mickey Rourke, Jos...
# 1  Chris Evans, Hayley Atwell, Sebastian Stan, To...
# 2  Johnny Depp, Pen├⌐lope Cruz, Geoffrey Rush, Ia...
# 3  Andrew Garfield, Emma Stone, Rhys Ifans, Denis...
# 4  Ashley Tisdale, Simon Rex, Charlie Sheen, Grac...
#
#                                     country  date_added  release_year  rating  \
# 0                  United States of America  2014-08-20          2014    6.39
# 1                  United States of America  2011-07-22          2011    7.00
# 2  United Kingdom, United States of America  2011-05-15          2011    6.56
# 3                  United States of America  2012-06-23          2012    6.70
# 4                  United States of America  2013-04-11          2013    4.80
#
#   duration                              genres language  \
# 0     None             Crime, Action, Thriller       en
# 1     None  Action, Adventure, Science Fiction       en
# 2     None          Adventure, Action, Fantasy       en
# 3     None  Action, Adventure, Science Fiction       en
# 4     None                              Comedy       en
#
#                                          description  popularity  vote_count  \
# 0  Some of Sin City's most hard-boiled citizens c...      46.711        3882
# 1  During World War II, Steve Rogers is a sickly ...      83.313       21654
# 2  Captain Jack Sparrow crosses paths with a woma...     102.748       14166
# 3  Peter Parker is an outcast high schooler aband...      77.777       17552
# 4  Home with their newly-formed family, happy par...      45.980        2824
#
#    vote_average     budget     revenue
# 0          6.39   65000000    39407616
# 1          7.00  140000000   370569774
# 2          6.56  379000000  1046721266
# 3          6.70  215000000   757930663
# 4          4.80   20000000    78378744
#    show_id     type              title      director  \
# 0      767  TV Show  Ready Steady Cook  Julian Smith
# 1      877  TV Show            Caprica           NaN
# 2     1399  TV Show    Game of Thrones           NaN
# 3     1401  TV Show     Hell on Wheels           NaN
# 4     1402  TV Show   The Walking Dead           NaN
#
#                                         cast_members  \
# 0                                        Rylan Clark
# 1  Eric Stoltz, Esai Morales, Paula Malcomson, Al...
# 2  Peter Dinklage, Kit Harington, Nikolaj Coster-...
# 3  Anson Mount, Colm Meaney, Robin McLeavy, Chris...
# 4  Lauren Cohan, Norman Reedus, Jeffrey Dean Morg...
#
#                                             country  date_added  release_year  \
# 0                                    United Kingdom  2020-03-02          2020
# 1                          United States of America  2010-01-22          2010
# 2          United Kingdom, United States of America  2011-04-17          2011
# 3  Canada, United Kingdom, United States of America  2011-11-06          2011
# 4                          United States of America  2010-10-31          2010
#
#    rating   duration                                       genres language  \
# 0     6.0  1 Seasons                                      Unknown       en
# 1     6.9  1 Seasons                      Drama, Sci-Fi & Fantasy       en
# 2     8.5  1 Seasons  Sci-Fi & Fantasy, Drama, Action & Adventure       en
# 3     7.6  1 Seasons           Action & Adventure, Drama, Western       en
# 4     8.1  1 Seasons  Action & Adventure, Drama, Sci-Fi & Fantasy       en
#
#                                          description  popularity  vote_count  \
# 0  Rylan Clark-Neal puts the next generation of c...      16.778           1
# 1  Set 58 years before Battlestar Galactica, Capr...      35.596         364
# 2  Seven noble families fight for control of the ...     812.157       24664
# 3  The epic story of post-Civil War America, focu...     119.632         422
# 4  Sheriff's deputy Rick Grimes awakens from a co...     485.660       16790
#
#    vote_average
# 0           6.0
# 1           6.9
# 2           8.5
# 3           7.6
# 4           8.1
